# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import skvideo.io
import skvideo.datasets

# %%
video_data = skvideo.io.vread('../video/VID_20180325_143338.mp4')

# %%
video_data.shape
# Out:
# (1335, 480, 720, 3)

# %%
type(video_data)
# Out:
# numpy.ndarray

# %%
video_data[0].shape
# Out:
# (480, 720, 3)

# %%
plt.imshow(video_data[5])
plt.show()
